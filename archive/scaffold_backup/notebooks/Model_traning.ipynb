# %%
#-----------------------------------------
# 1. Load Local CSV
# -----------------------------------------
DATA_PATH = r"data/ml_master_table_1M.csv"   # <-- update your path

df = pd.read_csv(DATA_PATH)
#print("Dataset shape:", df.shape)
print(df.head())
